# %% [markdown]
# # Loading

# %%
from langchain_community.document_loaders import JSONLoader

# %%
import json
from pathlib import Path
from pprint import pprint


file_path='./data.json'
data = json.loads(Path(file_path).read_text())

pprint(data)
# Out:
# [{'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Printed paper (Glossy and non-glossy)',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Printed paper (Glossy and non-glossy)']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Writing paper',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Writing paper']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Paper',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Paper',
#                     'Exam Papers',
#                     'Notes',
#                     'Notebook',
#                     'Mail',
#                     'Letter',
#                     'Bill',
#                     'Foolscap Paper',
#                     'Exercise Book']},
#  {'instructions': 'Clothes should be donated if they are in good condition. '
#                   '<br/><br/> Click <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your clothes.',
#   'item': 'Clothes',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['T-Shirt',
#                     'Shorts',
#                     'Pants',
#                     'Skirt',
#                     'Jacket',
#                     'Shirts',
#                     'Tie',
#                     'Blouse',
#                     'Singlet',
#                     'Camisole',
#                     'Clothes']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Newspaper',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Newspaper']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Flyer (Glossy and non-glossy)',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Flyer (Glossy and non-glossy)']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Magazine (Glossy and non-glossy)',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Magazine (Glossy and non-glossy)']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Telephone directory',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Telephone directory']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Envelope (With and without plastic window)',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Envelope (With and without plastic window)']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Plastic envelope',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Plastic envelope']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Red packet',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Red packet']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Namecard',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Namecard']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Greeting card',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Greeting card']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Shredded paper',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Shredded paper']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Paper receipt',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Paper receipt']},
#  {'instructions': 'Please flatten before recycling.',
#   'item': 'Carton box',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Carton box']},
#  {'instructions': 'Please flatten before recycling.',
#   'item': 'Cardboard box',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Cardboard box']},
#  {'instructions': 'Please flatten before recycling.',
#   'item': 'Printed paper box',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Printed paper box']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Paper egg trays',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Paper egg trays']},
#  {'instructions': 'Please empty, rinse and flatten before recycling.',
#   'item': 'Milk carton',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Marigold',
#                     'F&N',
#                     'Meiji',
#                     'Oatly',
#                     'Oatside',
#                     'HL',
#                     'Vitasoy',
#                     'Greenfield',
#                     'Farm Fresh']},
#  {'instructions': 'Please empty, rinse and flatten before recycling.',
#   'item': 'Drink packet',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Juice',
#                     'Pokka',
#                     'Milo',
#                     "Yeo's ",
#                     'Ribena',
#                     'Green Tea',
#                     'Ice Lemon Tea',
#                     'Lychee Tea',
#                     'Marigold',
#                     'Peel Fresh',
#                     'Orange Juice',
#                     'Apple Juice',
#                     'FNN',
#                     'Seasons',
#                     'Meiji',
#                     'Oatly',
#                     'Oatside',
#                     'HL',
#                     'Fruit Juice Packet',
#                     'Hojicha Tea',
#                     'Oolong Tea ',
#                     'Vitasoy']},
#  {'instructions': 'Please empty, rinse and flatten before recycling.',
#   'item': 'Juice packet',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['',
#                     'Pokka',
#                     "Yeo's ",
#                     'Ribena',
#                     'Green Tea',
#                     'Ice Lemon Tea',
#                     'Lychee Tea',
#                     'Marigold',
#                     'Peel Fresh',
#                     'Orange Juice',
#                     'Apple Juice',
#                     'FNN',
#                     'Seasons',
#                     'Fruit Juice Packet',
#                     'Hojicha Tea',
#                     'Oolong Tea ']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Paper towel tube',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Kitchen Towel', 'Kitchen Roll', 'Scotts']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Toilet roll tube',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Toilet roll tube']},
#  {'instructions': 'Please flatten.',
#   'item': 'Tissue box',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Tissue box']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Paper bag',
#   'material': 'Paper',
#   'recyclable': True,
#   'similar_items': ['Paper bag', 'Gift bag']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Paper disposables',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Paper disposables']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Paper cup',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Paper cup']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Paper plate',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Paper plate']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Glitter paper',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Glitter paper']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Crayon drawing',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Crayon drawing']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Tissue paper',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Tissue paper']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Paper towel',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Paper towel', 'Kitchen Towel', 'Kitchen Roll', 'Scotts']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Toilet paper',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Toilet paper']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Disposable wooden chopsticks',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Disposable wooden chopsticks']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Wooden chopsticks',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Wooden chopsticks']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Pizza boxes',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Pizza boxes']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Wax paper',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Wax paper', 'Baking Paper', 'Parchment Paper']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Paper packaging contaminated with food',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Paper packaging contaminated with food',
#                     'Takeaway',
#                     'Containers',
#                     'Baking Paper']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Paper packaging with food',
#   'material': 'Paper',
#   'recyclable': False,
#   'similar_items': ['Paper packaging with food', 'Takeaway', 'Containers']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Plastic bottle',
#   'material': 'F&B Plastic',
#   'recyclable': True,
#   'similar_items': ['Plastic bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Plastic container',
#   'material': 'F&B Plastic',
#   'recyclable': True,
#   'similar_items': ['Plastic container']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Soft drink bottle',
#   'material': 'F&B Plastic',
#   'recyclable': True,
#   'similar_items': ['Soft drink bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Carbonated drink bottle',
#   'material': 'F&B Plastic',
#   'recyclable': True,
#   'similar_items': ['Carbonated drink bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Milk bottles',
#   'material': 'F&B Plastic',
#   'recyclable': True,
#   'similar_items': ['Milk bottles']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Medicine bottle',
#   'material': 'F&B Plastic',
#   'recyclable': True,
#   'similar_items': ['Medicine bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Shampoo bottle',
#   'material': 'Non Food Plastic',
#   'recyclable': True,
#   'similar_items': ['Shampoo bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Bodywash bottle',
#   'material': 'Non Food Plastic',
#   'recyclable': True,
#   'similar_items': ['Bodywash bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Facial cleanser bottle',
#   'material': 'Non Food Plastic',
#   'recyclable': True,
#   'similar_items': ['Facial cleanser bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Detergent bottle',
#   'material': 'Non Food Plastic',
#   'recyclable': True,
#   'similar_items': ['Detergent bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Soap bottle',
#   'material': 'Non Food Plastic',
#   'recyclable': True,
#   'similar_items': ['Soap bottle']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'DVD',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['DVD']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'CD casing',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['CD casing']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'DVD casing',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['DVD casing']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Plastic bag',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Plastic bag']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Toilet paper packaging',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Toilet paper packaging']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Tissue box packaging',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Tissue box packaging']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Plastic film',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Plastic film']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Magazine wrapper',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Magazine wrapper']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Plastic packaging for packet drink',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Plastic packaging for packet drink']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Bubble wrap',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Bubble wrap']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Fruit box',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Fruit box']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Ziplock bag',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Ziplock bag']},
#  {'instructions': 'Please empty contents before recycling.',
#   'item': 'Plastic packaging',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Plastic packaging']},
#  {'instructions': 'Please empty contents before recycling.',
#   'item': 'Plastic egg trays',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Plastic egg trays']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Plastic clothes hanger',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Plastic clothes hanger']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Plastic takeaway food container',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Plastic takeaway food container']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Bubble tea cups',
#   'material': 'Plastic',
#   'recyclable': True,
#   'similar_items': ['Bubble tea cups']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Polystyrene foam product',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Polystyrene foam product']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Styrofoam',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Styrofoam']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Styrofoam cup',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Styrofoam cup']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Styrofoam clamshell container',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Styrofoam clamshell container']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Plastic disposables',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Plastic disposables']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Plastic crockery',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Plastic crockery']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Plastic packaging with foil',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Plastic packaging with foil']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Potato chip bags',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Potato chip bags']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Expired credit cards',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Expired credit cards']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Oxo-degradable bag',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Oxo-degradable bag']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Bio-degradable bag',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Bio-degradable bag']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Drinking straw',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Drinking straw']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Cassette',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Cassette']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Video tape',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Video tape']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Plastic packaging contaminated with food/oil stains',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Plastic packaging contaminated with food/oil stains']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Melamine products',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Melamine products']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Melamine cups',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Melamine cups']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Melamine plates',
#   'material': 'Plastic',
#   'recyclable': False,
#   'similar_items': ['Melamine plates']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Beverage glass bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Beverage glass bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Glass bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Glass bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Wine bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Wine bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Liquor bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Liquor bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Food glass bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Food glass bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Sauce bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Sauce bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Condiment bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Condiment bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Jam spread bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Jam spread bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Food jars',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Food jars']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Cosmetic glass bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Cosmetic glass bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Perfume glass bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Perfume glass bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Medicine glass bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Medicine glass bottle']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Supplement glass bottle',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Supplement glass bottle']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Glassware',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Glassware']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Glass cup',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Glass cup']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Glass plate',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Glass plate']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Drinking glass',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Drinking glass']},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'Wine glass',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Wine glass']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Borosilicate glassware',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Borosilicate glassware']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Pyrex glassware',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Pyrex glassware']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Bakeware',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Bakeware']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Tempered glass',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Tempered glass']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Oven-safe food containers',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Oven-safe food containers']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Crystal glass',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Crystal glass']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Glass with metal wires',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Glass with metal wires']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Windows',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Windows']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Mirror',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Mirror']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Ceramic products',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Ceramic products']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Ceramic plate',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Ceramic plate']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Tea pot',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Tea pot']},
#  {'instructions': 'should be donated if it can be reused.',
#   'item': 'Porcelain',
#   'material': 'Glass',
#   'recyclable': False,
#   'similar_items': ['Porcelain']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'Light bulb',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Light bulb']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'Lamp',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Lamp']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'Tube',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Tube']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'Incandescent lamp',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Incandescent lamp']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'Fluorescent lamp',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Fluorescent lamp']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'Incandescent bulb',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Incandescent bulb']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'Fluorescent bulb',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['Fluorescent bulb']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'LED lamp',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['LED lamp']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'LED bulb',
#   'material': 'Glass',
#   'recyclable': True,
#   'similar_items': ['LED bulb']},
#  {'instructions': '• Please empty and rinse before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Beverage metal can',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Beverage metal can']},
#  {'instructions': '• Please empty and rinse before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Carbonated drink can',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Carbonated drink can', 'Soda cans']},
#  {'instructions': '• Please empty and rinse before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Soft drink can',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Soft drink can']},
#  {'instructions': '• Please empty and rinse before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Beer can',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Beer can']},
#  {'instructions': '• Please empty and rinse before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Food metal can',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Food metal can']},
#  {'instructions': '• Please empty and rinse before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Biscuit tin',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Biscuit tin']},
#  {'instructions': '• Please empty and rinse before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Food tin',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Food tin']},
#  {'instructions': '• Please empty and rinse before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Canned food',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Canned food']},
#  {'instructions': '• Make sure it is clean before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Medals',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Medals']},
#  {'instructions': '• Please empty and rinse before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Metal container',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Metal container']},
#  {'instructions': '• Make sure it is clean before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Metal bottle cap',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Metal bottle cap']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Clean aluminium tray',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Clean aluminium tray']},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'Clean aluminium foil',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Clean aluminium foil']},
#  {'instructions': '• Please empty contents before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Non-food metal container',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Non-food metal container']},
#  {'instructions': '• Please empty contents before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Paint container',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Paint container']},
#  {'instructions': '• Please empty contents before recycling. <br/> • Rusted '
#                   'metals should be disposed of as general waste.',
#   'item': 'Paint cans',
#   'material': 'Metal',
#   'recyclable': True,
#   'similar_items': ['Paint cans']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Laptop',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Laptop']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Router',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Router']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Docking station',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Docking station']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Hard disk drive',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Hard disk drive']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Computer mouse',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Computer mouse']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'Household battery',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Household battery']},
#  {'instructions': 'should be donated if they are in good condition.',
#   'item': 'Bag',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Bag']},
#  {'instructions': 'should be donated if they are in good condition. <br/><br/> '
#                   'Click <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your furniture.',
#   'item': 'Toys',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Toys',
#                     'football',
#                     'basketball',
#                     'golf ball',
#                     'tennis ball']},
#  {'instructions': 'should be donated if they are in good condition.',
#   'item': 'Umbrella',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Umbrella']},
#  {'instructions': 'should be donated if they are in good condition.',
#   'item': 'Spectacles',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Spectacles', 'Glasses']},
#  {'instructions': 'should be donated if they are in good condition.',
#   'item': 'Textile',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Textile', 'Fabric']},
#  {'instructions': 'should be donated if they are in good condition.',
#   'item': 'Curtains',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Curtains']},
#  {'instructions': 'should be donated if they are in good condition.',
#   'item': 'Bedsheet',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Bedsheet']},
#  {'instructions': 'should be donated if they are in good condition.',
#   'item': 'Blanket',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Blanket']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Food waste',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Food waste']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Leftover medicine',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Leftover medicine']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Diaper',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Diaper', 'Pampers']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Sanitary pad',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Sanitary pad']},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'Stationery',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Stationery']},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'Pen',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Pen']},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'Pencil',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Pencil']},
#  {'instructions': 'Only for landed estates: Bag and place outside your unit on '
#                   'collection days.',
#   'item': 'Plant waste',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Plant waste']},
#  {'instructions': 'Only for landed estates: Bag and place outside your unit on '
#                   'collection days.',
#   'item': 'Horticultural waste',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Horticultural waste']},
#  {'instructions': 'should be donated if it is in good condition. <br/><br/> '
#                   'Click <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your luggage bag.',
#   'item': 'Luggage bag',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Luggage bag']},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises. <br/><br/> Click '
#                   '<a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your furniture.',
#   'item': 'Furniture',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Furniture']},
#  {'instructions': 'Repair or donate your used shoes as far as possible. '
#                   '<br/><br/>These are part of the permanent used shoe '
#                   'collection drive:<br/> • ActiveSG Sport Centres <br/>• '
#                   'Decathlon <br/>• Selected Public Parks <br/>• Selected '
#                   'Recreation Clubs and more! <br/><br/> Click <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your shoes.',
#   'item': 'Sports shoes',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Sports shoes']},
#  {'instructions': 'Repair or donate your used shoes as far as possible. '
#                   '<br/><br/>These are part of the permanent used shoe '
#                   'collection drive:<br/> • ActiveSG Sport Centres <br/>• '
#                   'Decathlon <br/>• Selected Public Parks <br/>• Selected '
#                   'Recreation Clubs and more! <br/><br/> Click <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your shoes.',
#   'item': 'School shoes',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['School shoes']},
#  {'instructions': 'Repair or donate your used shoes as far as possible. '
#                   '<br/><br/>These are part of the permanent used shoe '
#                   'collection drive:<br/> • ActiveSG Sport Centres <br/>• '
#                   'Decathlon <br/>• Selected Public Parks <br/>• Selected '
#                   'Recreation Clubs and more! <br/><br/> Click <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your shoes.',
#   'item': 'Football shoes (without metal studs)',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Football shoes (without metal studs)']},
#  {'instructions': 'can be recycled through: <br/>• Retailer 1-for-1 '
#                   'Take-back<br/>• Bulky item removal service by TCs for HDB '
#                   'residents<br/>• E-waste collection drive (Quarterly)<br/>• '
#                   'Doorstep collection (fees may apply) <br/><br/>To find out '
#                   'where you can recycle your e-waste, visit <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>",
#   'item': 'Large household appliances',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Large household appliances']},
#  {'instructions': 'can be recycled through: <br/>• Retailer 1-for-1 '
#                   'Take-back<br/>• Bulky item removal service by TCs for HDB '
#                   'residents<br/>• E-waste collection drive (Quarterly)<br/>• '
#                   'Doorstep collection (fees may apply) <br/><br/>To find out '
#                   'where you can recycle your e-waste, visit <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>",
#   'item': 'Refrigerator',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Refrigerator']},
#  {'instructions': 'can be recycled through: <br/>• Retailer 1-for-1 '
#                   'Take-back<br/>• Bulky item removal service by TCs for HDB '
#                   'residents<br/>• E-waste collection drive (Quarterly)<br/>• '
#                   'Doorstep collection (fees may apply) <br/><br/>To find out '
#                   'where you can recycle your e-waste, visit <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>",
#   'item': 'Fridge',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Fridge']},
#  {'instructions': 'can be recycled through: <br/>• Retailer 1-for-1 '
#                   'Take-back<br/>• Bulky item removal service by TCs for HDB '
#                   'residents<br/>• E-waste collection drive (Quarterly)<br/>• '
#                   'Doorstep collection (fees may apply) <br/><br/>To find out '
#                   'where you can recycle your e-waste, visit <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>",
#   'item': 'Washing machine',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Washing machine']},
#  {'instructions': 'can be recycled through: <br/>• Retailer 1-for-1 '
#                   'Take-back<br/>• Bulky item removal service by TCs for HDB '
#                   'residents<br/>• E-waste collection drive (Quarterly)<br/>• '
#                   'Doorstep collection (fees may apply) <br/><br/>To find out '
#                   'where you can recycle your e-waste, visit <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>",
#   'item': 'Dryer',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Dryer']},
#  {'instructions': 'can be recycled through: <br/>• Retailer 1-for-1 '
#                   'Take-back<br/>• Bulky item removal service by TCs for HDB '
#                   'residents<br/>• E-waste collection drive (Quarterly)<br/>• '
#                   'Doorstep collection (fees may apply) <br/><br/>To find out '
#                   'where you can recycle your e-waste, visit <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>",
#   'item': 'Television',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Television']},
#  {'instructions': 'can be recycled through: <br/>• Retailer 1-for-1 '
#                   'Take-back<br/>• Bulky item removal service by TCs for HDB '
#                   'residents<br/>• E-waste collection drive (Quarterly)<br/>• '
#                   'Doorstep collection (fees may apply) <br/><br/>To find out '
#                   'where you can recycle your e-waste, visit <a '
# ...
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Desktop monitor',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Desktop monitor']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Battery charger',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Battery charger']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Portable charger',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Portable charger']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Keyboard',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Keyboard']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '<br/><br/> Remember to tape the ends of the battery and '
#                   'seal leaking batteries in a leak-proof container or bag '
#                   'first to prevent short-circuit or fire incidents.',
#   'item': 'Rechargeable battery',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Rechargeable battery']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Desktop computer',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Desktop computer', 'IMac', 'Dell', 'Acer', 'HP ', 'ASUS']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Laptop',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Macbook',
#                     'Macbook Air',
#                     'Macbook Pro',
#                     'Lenovo',
#                     'HP',
#                     'ASUS',
#                     'Dell',
#                     'Razer',
#                     'Acer',
#                     'Samsung']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Tablet computer',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['IPad', 'Lenovo', 'HP', 'ASUS', 'Dell', 'Acer', 'Samsung']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Mobile phone',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Iphone',
#                     'Android',
#                     'Samsung',
#                     'Nokia',
#                     'Google Phone',
#                     'Apple',
#                     'Handphone',
#                     'Cellphone']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Computer battery',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Computer battery']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Printer',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Printer']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Modem',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Modem']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Power bank',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Power bank']},
#  {'instructions': 'can be recycled through E-waste bins, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Electronic cables',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Electronic cables',
#                     'Type C',
#                     'Type B',
#                     'HDMI Cable',
#                     'Razor',
#                     'USB C',
#                     'USB',
#                     'Lightning cable',
#                     'ADAT',
#                     'Fire-Wire',
#                     'TS',
#                     'TRS',
#                     'XLR']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>.",
#   'item': 'Electronic waste',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Iphone',
#                     'Android',
#                     'Samsung',
#                     'Nokia',
#                     'Google Phone',
#                     'Macbook',
#                     'Macbook Air',
#                     'Macbook Pro',
#                     'Apple',
#                     'Handphone',
#                     'Cellphone',
#                     'Ipad',
#                     'Electronic waste']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins).',
#   'item': 'Household battery',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Energizer', 'Duracell', 'Eveready']},
#  {'instructions': 'can be recycled at e-waste collection points, located <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a>. "
#                   '(ALBA E-waste recycling Bins)',
#   'item': 'Alkaline battery',
#   'material': 'Others',
#   'recyclable': True,
#   'similar_items': ['Alkaline battery']},
#  {'instructions': 'should be donated if they are in good condition. <br/><br/> '
#                   'Click <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your shoes.',
#   'item': 'Shoes',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Shoes',
#                     'Heels',
#                     'Sandles',
#                     'Crocs',
#                     'Sneakers',
#                     'Pumps',
#                     'Dress shoes',
#                     'Sneakers',
#                     'Nike',
#                     'Adidas',
#                     'Asics',
#                     'Puma',
#                     'Reebok',
#                     'New Balance',
#                     'Sketchers',
#                     'Under Armour',
#                     'boots',
#                     'roller blades',
#                     'roller skates']},
#  {'instructions': 'should be disposed of as general waste.',
#   'item': 'Food waste',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['pizza',
#                     'drumstick',
#                     'spoiled food',
#                     'rotten food',
#                     'food peels',
#                     'leftovers',
#                     'noodles',
#                     'rice',
#                     'biscuits',
#                     'crackers',
#                     'cookies',
#                     'chocolate',
#                     'sweets',
#                     'candy',
#                     'gummy bears',
#                     'meat',
#                     'fish',
#                     'seafood',
#                     'vegetables']},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'Stationery',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['marker',
#                     'whiteboard marker',
#                     'permanent Marker',
#                     'Ruler',
#                     'Highlighter',
#                     'Correction tape',
#                     'Correction liquid',
#                     'eraser']},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'Bulky waste',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Bulky waste',
#                     'cushion',
#                     'Fan',
#                     'Couch',
#                     'Sofa',
#                     'Chair',
#                     'Coffee Table',
#                     'Mattress',
#                     'Bed Frame',
#                     'dining table',
#                     'stool',
#                     'cupboard',
#                     'cabinet',
#                     'iron',
#                     'ironing board',
#                     'shoe rack']},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises. <br/><br/> Click '
#                   '<a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your furniture.',
#   'item': 'Furniture',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Fan',
#                     'Couch',
#                     'Sofa',
#                     'Chair',
#                     'Coffee Table',
#                     'Mattress',
#                     'Bed Frame',
#                     'dining table',
#                     'stool',
#                     'cupboard',
#                     'cabinet',
#                     'shoe rack']},
#  {'instructions': 'Repair or donate your used shoes as far as possible. '
#                   '<br/><br/>These are part of the permanent used shoe '
#                   'collection drive:<br/> • ActiveSG Sport Centres <br/>• '
#                   'Decathlon <br/>• Selected Public Parks <br/>• Selected '
#                   'Recreation Clubs and more! <br/><br/> Click <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your shoes.',
#   'item': 'Sports shoes',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Sneakers',
#                     'Nike',
#                     'Adidas',
#                     'Asics',
#                     'Puma',
#                     'Reebok',
#                     'New Balance',
#                     'Sketchers',
#                     'Under Armour']},
#  {'instructions': 'Repair or donate your used shoes as far as possible. '
#                   '<br/><br/>These are part of the permanent used shoe '
#                   'collection drive:<br/> • ActiveSG Sport Centres <br/>• '
#                   'Decathlon <br/>• Selected Public Parks <br/>• Selected '
#                   'Recreation Clubs and more! <br/><br/> Click <a '
#                   "href='https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/' "
#                   "target='_blank' style='color:black; font-weight:600; "
#                   "text-decoration: underline; font-style: italic;'>here</a> "
#                   'for avenues to donate, resell or repair your shoes.',
#   'item': 'School shoes',
#   'material': 'Others',
#   'recyclable': False,
#   'similar_items': ['Sneakers',
#                     'Nike',
#                     'Adidas',
#                     'Asics',
#                     'Puma',
#                     'Reebok',
#                     'New Balance',
#                     'Sketchers']}]

# %%
item_names = set()
data_cleaned = []
for d in data:
    if d['item'] not in item_names:
        data_cleaned.append(d)
        item_names.add(d['item'])

# %%
# save to json file
with open('./data_cleaned.json', 'w') as file:
    json.dump(data_cleaned, file)

# %%
loader = JSONLoader(
    file_path='./data_cleaned.json',
    jq_schema='.[] | {material, item, similar_items, recyclable, instructions}',
    text_content=False,
    # metadata_func=lambda doc, index: {
    #     "doc": doc,
    #     "index": index
    # }
    )

docs = loader.load()

# %%
# # remove the irrelevant fields in the content
# def extract_relevant_fields(page_content: dict):
#     return {
#         "material": page_content.get('material', None),
#         "item": page_content.get('item', None),
#         "similar_items": page_content.get('similar_items', [])
#     }

# for i in range(len(docs)):
#     content_json = json.loads(docs[i].page_content)
#     docs[i].page_content = json.dumps(extract_relevant_fields(content_json))

# %% [markdown]
# # Splitting

# %%
# No splitting as each document has relatively small tokens

# %% [markdown]
# # Embedding

# %%
from langchain_openai import OpenAIEmbeddings

embedder = OpenAIEmbeddings(model='text-embedding-ada-002')

# %% [markdown]
# # Vector Store

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_pinecone import PineconeVectorStore
import os 

index_name = os.getenv("PINECONE_INDEX_NAME")

docsearch = PineconeVectorStore.from_documents(docs, embedder, index_name=index_name)

# %%
# query = "The item is potato chips bag. Is it recyclable?"
query = "The item in the image is a plastic wrapper for an A4 paper ream, branded by PaperOne."
docs = docsearch.similarity_search(query)

for doc in docs:
    print(doc.page_content, end='\n\n')
# Out:
# {"material": "Paper", "item": "Plastic envelope", "similar_items": ["Plastic envelope"], "recyclable": true, "instructions": "Make sure it is clean before recycling."}
#
# {"material": "Paper", "item": "Printed paper (Glossy and non-glossy)", "similar_items": ["Printed paper (Glossy and non-glossy)"], "recyclable": true, "instructions": "Make sure it is clean before recycling."}
#
# {"material": "Plastic", "item": "Toilet paper packaging", "similar_items": ["Toilet paper packaging"], "recyclable": true, "instructions": "Make sure it is clean before recycling."}
#
# {"material": "Paper", "item": "Paper Packaging (printed paper box etc)", "similar_items": ["Gifts", "Presents"], "recyclable": true, "instructions": "Please flatten before recycling."}

# %%
# query = "The item is potato chips bag. Is it recyclable?"
query = "The item in the image is a plastic wrapper for an A4 paper ream, branded by PaperOne."
docs = docsearch.max_marginal_relevance_search(query)

for doc in docs:
    print(doc.page_content, end='\n\n')
# Out:
# {"material": "Paper", "item": "Printed paper (Glossy and non-glossy)", "recyclable": "YES!", "instructions": "Make sure it is clean before recycling.", "similar_items": ["Exam Papers ", "Notes", "Notebook", "Mail", "Letter", "Stamps"]}
#
# {"material": "Paper", "item": "Beverage carton", "recyclable": "YES!", "instructions": "Please empty, rinse and flatten before recycling.", "similar_items": ["Beverage carton", "Juice", "Pokka", "Milo", "Yeo's ", "Ribena", "Green Tea", "Ice Lemon Tea", "Lychee Tea", "Marigold", "Peel Fresh", "Orange Juice", "Apple Juice", "FNN", "Seasons", "Meiji", "Oatly", "Oatside", "HL", "Fruit Juice Packet", "Hojicha Tea", "Oolong Tea ", "Vitasoy", "F&N", "Greenfield", "Farm Fresh"]}
#
# {"material": "Others", "item": "Plastic food wrap", "recyclable": "YES!", "instructions": "Make sure it is clean before recycling.", "similar_items": ["Plastic food wrap"]}
#
# {"material": "Paper", "item": "Paper packaging contaminated with food", "recyclable": "NO!", "instructions": "should be disposed of as general waste.", "similar_items": ["Paper packaging contaminated with food", "Takeaway", "Containers", "Baking Paper"]}
# /tmp/ipykernel_40347/2572351503.py:3: RuntimeWarning: coroutine 'VectorStore.amax_marginal_relevance_search' was never awaited
#   docs = docsearch.max_marginal_relevance_search(query)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
from langchain.vectorstores import Chroma

# %%
persist_directory = 'docs/chroma'

# %%
# !rm -rf ./docs/chroma  # remove old database files if any
# !rmdir docs

# %%
vectordb = Chroma.from_documents(
    documents=docs,
    embedding=embedder,
    persist_directory=persist_directory
)

# %%
print(vectordb._collection.count())
# Out:
# 322

# %%
question = "The item in the image is a plastic wrapper for an A4 paper ream, branded by PaperOne."

# %%
docs = vectordb.max_marginal_relevance_search(question, k=5)

for doc in docs:
    print(doc.metadata, end='\n\n')
# Out:
# {'seq_num': 218, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}
#
# {'seq_num': 238, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}
#
# {'seq_num': 240, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}
#
# {'seq_num': 39, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}
#
# {'seq_num': 291, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}

# %%
vectordb.add_documents()
# Out:
# {'lc': 1,
#  'type': 'constructor',
#  'id': ['langchain', 'schema', 'document', 'Document'],
#  'kwargs': {'page_content': '{"material": "Paper", "item": "Printed paper box", "recyclable": "YES!", "instructions": "Please flatten before recycling.", "similar_items": []}',
#   'metadata': {'seq_num': 238,
#    'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'},
#   'type': 'Document'}}

# %%
vectordb.
# Out:
# {'seq_num': 291,
#  'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}

# %%
from langchain.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings

# Initialize the embedding model and vector database
embedder = OpenAIEmbeddings()
vectordb = Chroma(persist_directory='docs/chroma', embedding=embedder)

# Example document
doc_content = {
    "id": "436",
    "material": "Others",
    "item": "Clothes",
    "recyclable": "NOT IN ME!",
    "instructions": "Clothes should be donated if they are in good condition...",
    "similar_items": ["T-Shirt", "Shorts", "Pants", "Skirt", "Jacket", "Shirts", "Tie", "Blouse", "Singlet", "Camisole", "Clothes"]
}

# Function to prepare text for embedding based on specific fields
def prepare_text_for_embedding(item, similar_items):
    return item + " " + " ".join(similar_items)

# Embedding the relevant fields
embedding_text = prepare_text_for_embedding(doc_content['item'], doc_content['similar_items'])
embedding_vector = embedder.get_embedding(embedding_text)

# Adding the document to Chroma with full document as metadata
vectordb.add_document(doc_content['id'], embedding_vector, metadata=doc_content)

# Function to retrieve a full document by ID
def get_full_document_by_id(doc_id):
    result = vectordb.get_document(doc_id)
    if result:
        return result.metadata
    return None

# Example of retrieving a document
retrieved_document = get_full_document_by_id("436")
print(retrieved_document)
# Out:
# '{"material": "Plastic", "item": "Plastic packaging for packet drink", "recyclable": "YES!", "instructions": "Make sure it is clean before recycling.", "similar_items": ["Plastic packaging for packet drink"]}'
