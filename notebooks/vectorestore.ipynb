# %% [markdown]
# # Loading

# %%
from langchain_community.document_loaders import JSONLoader

# %%
DATA_PATH = '../data/cleaned_data_final.json'

# %%
import json
from pathlib import Path
from pprint import pprint


file_path=DATA_PATH
data = json.loads(Path(file_path).read_text())

pprint(data)
# Out:
# [{'instructions': '9-Volt battery can be recycled at e-waste collection '
#                   'points, located at ALBA E-waste recycling bins.  Remember '
#                   'to tape the ends of the battery and seal leaking batteries '
#                   'in a leak-proof container or bag first to prevent '
#                   'short-circuit or fire incidents.',
#   'item': '9-volt battery',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Please empty contents before recycling to prevent fire '
#                   'incidents.',
#   'item': 'aerosol cans',
#   'links': [],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.',
#   'item': 'air conditioner',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled at e-waste collection points, located at '
#                   'ALBA E-waste recycling bins.',
#   'item': 'alkaline battery',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'ang pow',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'anniversary card',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Donate if it can be reused.',
#   'item': 'assessment books',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'atm card',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'audio sound system',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be donated if they are in good condition.',
#   'item': 'bag',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'baking paper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'bank card',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be donated if they are in good condition.  Refer to '
#                   'the link(s) to donate, resell or repair your furniture.',
#   'item': 'basketball',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'battery charger',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'bed frame',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be donated if they are in good condition.',
#   'item': 'bedsheet',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': '• Please empty and rinse before recycling.  • Rusted metals '
#                   'should be disposed of as general waste.',
#   'item': 'beer can',
#   'links': [],
#   'material': 'Metal',
#   'recyclable': True},
#  {'instructions': 'Please empty, rinse and flatten before recycling.',
#   'item': 'beverage carton',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'beverage glass bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': '• Please empty and rinse before recycling.  • Rusted metals '
#                   'should be disposed of as general waste.',
#   'item': 'beverage metal can',
#   'links': [],
#   'material': 'Metal',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'bill',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'bio-degradable bag',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'birthday card',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': '• Please empty and rinse before recycling.  • Rusted metals '
#                   'should be disposed of as general waste.',
#   'item': 'biscuit tin',
#   'links': [],
#   'material': 'Metal',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'biscuits',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be donated if they are in good condition.',
#   'item': 'blanket',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'blister pack',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Clothes should be donated if they are in good condition.  '
#                   'Refer to the link(s) to donate, resell or repair your '
#                   'clothes.',
#   'item': 'blouse',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it can be reused.',
#   'item': 'books',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be donated if they are in good condition.  Refer to '
#                   'the link(s) to donate, resell or repair your shoes.',
#   'item': 'boots',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be donated if it can be reused.',
#   'item': 'borosilicate glassware',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': False},
#  {'instructions': 'Briefcase should be donated if it is in good condition. '
#                   'Refer to the link(s) to donate, resell or repair your '
#                   'briefcase.',
#   'item': 'briefcase',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'brochure (glossy and non-glossy)',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'bubble tea cups',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'bubble wrap',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'bulky waste',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'business card',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Button cell battery can be recycled at e-waste collection '
#                   'points, located at ALBA E-waste recycling bins.  Remember '
#                   'to tape the ends of the battery and seal leaking batteries '
#                   'in a leak-proof container or bag first to prevent '
#                   'short-circuit or fire incidents.',
#   'item': 'button cell battery',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'cabinet',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'calendar',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Clothes should be donated if they are in good condition.  '
#                   'Refer to the link(s) to donate, resell or repair your '
#                   'clothes.',
#   'item': 'camisole',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'candy',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': '• Please empty and rinse before recycling.  • Rusted metals '
#                   'should be disposed of as general waste.',
#   'item': 'canned food',
#   'links': [],
#   'material': 'Metal',
#   'recyclable': True},
#  {'instructions': 'Please flatten before recycling.',
#   'item': 'cardboard box',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Please flatten before recycling.',
#   'item': 'carton box',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'cassette',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'cd',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'cd casing',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'cd player',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'cellphone',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be donated if it can be reused.',
#   'item': 'ceramic plate',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': False},
#  {'instructions': 'Should be donated if it can be reused.',
#   'item': 'ceramic products',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': False},
#  {'instructions': 'Please flatten before recycling.',
#   'item': 'cereal box',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'chair',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.  Refer to the '
#                   'link(s) to donate, resell or repair your chairs.',
#   'item': 'chairs',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Child seat should be donated if it is in good condition. '
#                   'Refer to the link(s) to donate, resell or repair your child '
#                   'seat.',
#   'item': 'child seat',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'chilli sauce bottle',
#   'links': [],
#   'material': 'F&B Plastic',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'chocolate',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'christmas card',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Ensure cigarette butts are stubbed out and not smouldering '
#                   'before disposing of as general waste.',
#   'item': 'cigarettes',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'clean aluminium foil',
#   'links': [],
#   'material': 'Metal',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'clean aluminium tray',
#   'links': [],
#   'material': 'Metal',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'cling film',
#   'links': [],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Clothes should be donated if they are in good condition.  '
#                   'Refer to the link(s) to donate, resell or repair your '
#                   'clothes.',
#   'item': 'clothes',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Coffee capsules can be recycled via channels such as '
#                   'Nespresso recycling points. Click here for more info.',
#   'item': 'coffee capsules',
#   'links': ['https://www.nespresso.com/sg/en/recycling-one-pod-at-a-time'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'coffee table',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it can be reused.',
#   'item': 'comic books',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'compact disc',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'computer battery',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'computer mouse',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'containers',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'cookies',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Cooking pot can be recycled if it is fully metal. '
#                   'Otherwise, it should be disposed of as general waste.',
#   'item': 'cooking pot',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'correction liquid',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'correction tape',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'cosmetic glass bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'cotton bud',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'cotton wool',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'couch',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'crackers',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'crayon drawing',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Should be donated if they are in good condition.  Refer to '
#                   'the link(s) to donate, resell or repair your shoes.',
#   'item': 'crocs',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be donated if it can be reused.',
#   'item': 'crystal glass',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'cupboard',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be donated if they are in good condition.',
#   'item': 'curtains',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'cushion',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'debit card',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'desktop computer',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'desktop monitor',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'detergent bottle',
#   'links': [],
#   'material': 'Non Food Plastic',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'diaper',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it can be reused.',
#   'item': 'diary',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'dining table',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'dirty aluminium foil',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'dirty aluminium tray',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'disposable bowl',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'disposable cup',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'disposable cutlery',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'disposable fork',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'disposable knife',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'disposable plate',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'disposable shaver',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'disposable spoon',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'disposable wooden chopsticks',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'docking station',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be donated if they are in good condition.  Refer to '
#                   'the link(s) to donate, resell or repair your shoes.',
#   'item': 'dress shoes',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Please empty, rinse and flatten before recycling.',
#   'item': 'drink packet',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'drinking glass',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'drinking straw',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'drumstick',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'dvd',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'dvd casing',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'dvd player',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.',
#   'item': 'e-scooter',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.',
#   'item': 'electric bicycle',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'electric fan',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'electric kettle',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.',
#   'item': 'electric mobility devices',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.',
#   'item': 'electric mobility scooter',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.',
#   'item': 'electric scooter',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Electric shaver can be recycled through E-waste bins, '
#                   'located at the link(s).',
#   'item': 'electric shaver',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'electronic cables',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled at e-waste collection points, located here.',
#   'item': 'electronic waste',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'envelope (with and without plastic window)',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'eraser',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'exam papers',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'exercise book',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'expired credit cards',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be donated if they are in good condition.',
#   'item': 'fabric',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'fan',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'fire wire',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'fish',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled at e-waste collection points, located at '
#                   'ALBA E-waste recycling bins.',
#   'item': 'fluorescent bulb',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Can be recycled at e-waste collection points, located at '
#                   'ALBA E-waste recycling bins.',
#   'item': 'fluorescent lamp',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'flyer (glossy and non-glossy)',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'food blender',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'food glass bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'food jars',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': '• Please empty and rinse before recycling.  • Rusted metals '
#                   'should be disposed of as general waste.',
#   'item': 'food metal can',
#   'links': [],
#   'material': 'Metal',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'food peels',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'food processor',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': '• Please empty and rinse before recycling.  • Rusted metals '
#                   'should be disposed of as general waste.',
#   'item': 'food tin',
#   'links': [],
#   'material': 'Metal',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'food waste',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'foolscap paper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be donated if they are in good condition.  Refer to '
#                   'the link(s) to donate, resell or repair your furniture.',
#   'item': 'football',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Repair or donate your used shoes as far as possible. These '
#                   'are part of the permanent used shoe collection drive: • '
#                   'ActiveSG Sport Centres • Decathlon • Selected Public Parks '
#                   '• Selected Recreation Clubs and more!  Refer to the link(s) '
#                   'to donate, resell or repair your shoes.',
#   'item': 'football shoes (without metal studs)',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here',
#   'item': 'fridge',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'fruit box',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.  Refer to the '
#                   'link(s) to donate, resell or repair your furniture.',
#   'item': 'furniture',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'gaming console',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Please flatten before recycling.',
#   'item': 'gift',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'gift bag',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'gift wrapping paper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Please flatten before recycling.',
#   'item': 'gifts',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'glad wrap',
#   'links': [],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be donated if it can be reused.',
#   'item': 'glass bakeware',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': False},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'glass beer bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'glass bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'glass condiment bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'glass cup',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'glass plate',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'glass sauce bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Can be recycled at e-waste collection points, located at '
#                   'ALBA E-waste recycling bins.',
#   'item': 'glass tube',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'glass wine bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'glass with metal wires',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': False},
#  {'instructions': 'Should be donated if they are in good condition.',
#   'item': 'glasses',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'glassware',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'glitter paper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Should be donated if they are in good condition.  Refer to '
#                   'the link(s) to donate, resell or repair your furniture.',
#   'item': 'golf ball',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it can be reused.',
#   'item': 'graph paper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'green packet',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'greeting card',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'gummy bears',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here',
#   'item': 'hairdryer',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'handphone',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'hard disk drive',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be donated if they are in good condition.  Refer to '
#                   'the link(s) to donate, resell or repair your shoes.',
#   'item': 'heels',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'highlighter',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'hong bao',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Only for landed estates: Bag and place outside your unit on '
#                   'collection days.',
#   'item': 'horticultural waste',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled at e-waste collection points, located at '
#                   'ALBA E-waste recycling bins.',
#   'item': 'household battery',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Can be recycled at e-waste collection points, located at '
#                   'ALBA E-waste recycling bins.',
#   'item': 'incandescent bulb',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Can be recycled at e-waste collection points, located at '
#                   'ALBA E-waste recycling bins.',
#   'item': 'incandescent lamp',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'iron',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'ironing board',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Clothes should be donated if they are in good condition.  '
#                   'Refer to the link(s) to donate, resell or repair your '
#                   'clothes.',
#   'item': 'jacket',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'jam spread bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Ensure joss sticks are stubbed out and not smouldering '
#                   'before disposing of as general waste.',
#   'item': 'joss sticks',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it can be reused.',
#   'item': 'jotter book',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'journal',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Please empty, rinse and flatten before recycling.',
#   'item': 'juice packet',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'ketchup bottle',
#   'links': [],
#   'material': 'F&B Plastic',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'keyboard',
# ...
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'speaker',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be donated if they are in good condition.',
#   'item': 'spectacles',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'spoiled food',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Repair or donate your used shoes as far as possible. These '
#                   'are part of the permanent used shoe collection drive: • '
#                   'ActiveSG Sport Centres • Decathlon • Selected Public Parks '
#                   '• Selected Recreation Clubs and more!  Refer to the link(s) '
#                   'to donate, resell or repair your shoes.',
#   'item': 'sports shoes',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Please empty contents before recycling to prevent fire '
#                   'incidents.',
#   'item': 'spray cans',
#   'links': [],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'stamps',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'standing fan',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'stationery',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure that they are completely metal.',
#   'item': 'steel wool',
#   'links': [],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.',
#   'item': 'stool',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it can be reused.',
#   'item': 'storybook',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'styrofoam',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'styrofoam clamshell container',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'styrofoam cup',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'supplement glass bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'sweets',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'switch',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Clothes should be donated if they are in good condition.  '
#                   'Refer to the link(s) to donate, resell or repair your '
#                   'clothes.',
#   'item': 't-shirt',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it is in good condition or contact Town Council '
#                   'to remove from your residential premises.  Refer to the '
#                   'link(s) to donate, resell or repair your table.',
#   'item': 'table',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through E-waste bins, located at the '
#                   'link(s).',
#   'item': 'tablet computer',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'takeaway',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Should be donated if it can be reused.',
#   'item': 'tea pot',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'telephone directory',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here',
#   'item': 'television',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be donated if it can be reused.',
#   'item': 'tempered glass',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': False},
#  {'instructions': 'Should be donated if they are in good condition.  Refer to '
#                   'the link(s) to donate, resell or repair your furniture.',
#   'item': 'tennis ball',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Donate if it can be reused.',
#   'item': 'textbooks',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be donated if they are in good condition.',
#   'item': 'textile',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Clothes should be donated if they are in good condition.  '
#                   'Refer to the link(s) to donate, resell or repair your '
#                   'clothes.',
#   'item': 'tie',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Please flatten.',
#   'item': 'tissue box',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'tissue box packaging',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'tissue paper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'toaster oven',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'toilet paper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'toilet paper packaging',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'toilet roll tube',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Should be donated if they are in good condition.  Refer to '
#                   'the link(s) to donate, resell or repair your furniture.',
#   'item': 'toys',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here',
#   'item': 'tv',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be donated if they are in good condition.',
#   'item': 'umbrella',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'vacuum cleaner',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Vase should be donated if it is in good condition. Refer to '
#                   'the link(s) to donate, resell or repair your vase.',
#   'item': 'vase',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/donation-resale-and-repair-channels/'],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'vegetables',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'video tape',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': False},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here',
#   'item': 'washing machine',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'wax paper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'wet wipes',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'white wine bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Donate if it is in good condition.',
#   'item': 'whiteboard marker',
#   'links': [],
#   'material': 'Others',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'whskey glass',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Can be recycled through: • Retailer 1-for-1 Take-back• '
#                   'Bulky item removal service by TCs for HDB residents• '
#                   'E-waste collection drive (Quarterly)• Doorstep collection '
#                   '(fees may apply) To find out where you can recycle your '
#                   'e-waste, visit here.*Please note that the small household '
#                   'appliances will be collected and recycled under recycling '
#                   'programmes organised under the National Voluntary '
#                   'Partnership for the Proper Management of Non-Regulated Used '
#                   'Household Electrical/Electronic Products.',
#   'item': 'wii',
#   'links': ['https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste'],
#   'material': 'Others',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'windows',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': False},
#  {'instructions': 'Please empty and rinse before recycling.',
#   'item': 'wine bottle',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'wine glass',
#   'links': [],
#   'material': 'Glass',
#   'recyclable': True},
#  {'instructions': 'Should be disposed of as general waste.',
#   'item': 'wooden chopsticks',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': False},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'wrapper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'writing paper',
#   'links': [],
#   'material': 'Paper',
#   'recyclable': True},
#  {'instructions': 'Make sure it is clean before recycling.',
#   'item': 'ziplock bag',
#   'links': [],
#   'material': 'Plastic',
#   'recyclable': True}]

# %%
loader = JSONLoader(
    file_path=DATA_PATH,
    jq_schema='.[] | {material, item, recyclable, instructions, links}',
    text_content=False,
    # metadata_func=lambda doc, index: {
    #     "doc": doc,
    #     "index": index
    # }
    )

docs = loader.load()

# %%
# # remove the irrelevant fields in the content
# def extract_relevant_fields(page_content: dict):
#     return {
#         "material": page_content.get('material', None),
#         "item": page_content.get('item', None),
#         "similar_items": page_content.get('similar_items', [])
#     }

# for i in range(len(docs)):
#     content_json = json.loads(docs[i].page_content)
#     docs[i].page_content = json.dumps(extract_relevant_fields(content_json))

# %%
docs[0]
# Out:
# Document(metadata={'source': '/home/mightymagnus/projects/blooapp-api/data/cleaned_data_final.json', 'seq_num': 1}, page_content='{"material": "Others", "item": "9-volt battery", "recyclable": true, "instructions": "9-Volt battery can be recycled at e-waste collection points, located at ALBA E-waste recycling bins.  Remember to tape the ends of the battery and seal leaking batteries in a leak-proof container or bag first to prevent short-circuit or fire incidents.", "links": ["https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste"]}')

# %% [markdown]
# # Splitting

# %%
# No splitting as each document has relatively small tokens

# %% [markdown]
# # Embedding

# %%
from langchain_openai import OpenAIEmbeddings

embedder = OpenAIEmbeddings(model='text-embedding-ada-002')

# %% [markdown]
# # Vector Store

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_pinecone import PineconeVectorStore
import os 

index_name = os.getenv("PINECONE_INDEX_NAME")

docsearch = PineconeVectorStore.from_documents(docs, embedder, index_name=index_name)

# %%
query = "styrofoam, toothpase tube"

# %%
# query = "The item is potato chips bag. Is it recyclable?"
docs = docsearch.similarity_search(query)

for doc in docs:
    print(doc.page_content, end='\n\n')
# Out:
# {"material": "Plastic", "item": "styrofoam", "recyclable": false, "instructions": "Should be disposed of as general waste.", "links": []}
#
# {"material": "Plastic", "item": "styrofoam cup", "recyclable": false, "instructions": "Should be disposed of as general waste.", "links": []}
#
# {"material": "Plastic", "item": "styrofoam clamshell container", "recyclable": false, "instructions": "Should be disposed of as general waste.", "links": []}
#
# {"material": "Plastic", "item": "polystyrene foam product", "recyclable": false, "instructions": "Should be disposed of as general waste.", "links": []}

# %%
docs = docsearch.max_marginal_relevance_search(query)

for doc in docs:
    print(doc.page_content, end='\n\n')
# Out:
# {"material": "Plastic", "item": "styrofoam", "recyclable": false, "instructions": "Should be disposed of as general waste.", "links": []}
#
# {"material": "Glass", "item": "glass tube", "recyclable": true, "instructions": "Can be recycled at e-waste collection points, located at ALBA E-waste recycling bins.", "links": ["https://www.nea.gov.sg/our-services/waste-management/3r-programmes-and-resources/e-waste-management/where-to-recycle-e-waste"]}
#
# {"material": "Paper", "item": "paper towel tube", "recyclable": true, "instructions": "Make sure it is clean before recycling.", "links": []}
#
# {"material": "Plastic", "item": "plastic bubble tea carrier", "recyclable": true, "instructions": "Please empty contents before recycling.", "links": []}

# %% [markdown]
# # Using Chroma (in memory vector db)

# %%
from langchain.vectorstores import Chroma

# %%
persist_directory = 'docs/chroma'

# %%
# !rm -rf ./docs/chroma  # remove old database files if any
# !rmdir docs

# %%
vectordb = Chroma.from_documents(
    documents=docs,
    embedding=embedder,
    persist_directory=persist_directory
)

# %%
print(vectordb._collection.count())
# Out:
# 322

# %%
question = "The item in the image is a plastic wrapper for an A4 paper ream, branded by PaperOne."

# %%
docs = vectordb.max_marginal_relevance_search(question, k=5)

for doc in docs:
    print(doc.metadata, end='\n\n')
# Out:
# {'seq_num': 218, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}
#
# {'seq_num': 238, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}
#
# {'seq_num': 240, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}
#
# {'seq_num': 39, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}
#
# {'seq_num': 291, 'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}

# %%
vectordb.add_documents()
# Out:
# {'lc': 1,
#  'type': 'constructor',
#  'id': ['langchain', 'schema', 'document', 'Document'],
#  'kwargs': {'page_content': '{"material": "Paper", "item": "Printed paper box", "recyclable": "YES!", "instructions": "Please flatten before recycling.", "similar_items": []}',
#   'metadata': {'seq_num': 238,
#    'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'},
#   'type': 'Document'}}

# %%
vectordb.
# Out:
# {'seq_num': 291,
#  'source': '/home/mightymagnus/projects/blooapp-api/app/data.json'}

# %%
from langchain.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings

# Initialize the embedding model and vector database
embedder = OpenAIEmbeddings()
vectordb = Chroma(persist_directory='docs/chroma', embedding=embedder)

# Example document
doc_content = {
    "id": "436",
    "material": "Others",
    "item": "Clothes",
    "recyclable": "NOT IN ME!",
    "instructions": "Clothes should be donated if they are in good condition...",
    "similar_items": ["T-Shirt", "Shorts", "Pants", "Skirt", "Jacket", "Shirts", "Tie", "Blouse", "Singlet", "Camisole", "Clothes"]
}

# Function to prepare text for embedding based on specific fields
def prepare_text_for_embedding(item, similar_items):
    return item + " " + " ".join(similar_items)

# Embedding the relevant fields
embedding_text = prepare_text_for_embedding(doc_content['item'], doc_content['similar_items'])
embedding_vector = embedder.get_embedding(embedding_text)

# Adding the document to Chroma with full document as metadata
vectordb.add_document(doc_content['id'], embedding_vector, metadata=doc_content)

# Function to retrieve a full document by ID
def get_full_document_by_id(doc_id):
    result = vectordb.get_document(doc_id)
    if result:
        return result.metadata
    return None

# Example of retrieving a document
retrieved_document = get_full_document_by_id("436")
print(retrieved_document)
# Out:
# '{"material": "Plastic", "item": "Plastic packaging for packet drink", "recyclable": "YES!", "instructions": "Make sure it is clean before recycling.", "similar_items": ["Plastic packaging for packet drink"]}'
